# %% [markdown]
# ## Projet 8

# %% [markdown]
# ### Communiquez vos résultats

# %% [markdown]
# #### Option C : réaliser un projet libre dans le domaine professionnel qui vous intéresse

# %% [markdown]
# En démarrant ce parcours Data Analyst, vous aviez sûrement déjà un domaine de prédilection, voire un projet professionnel défini.
#
# Dans tous les cas, comprendre les problématiques d'un secteur et les métiers qui la composent est essentiel pour faire votre travail de data analyst. Vous ferez l'interface entre des données spécifiques et un représentant du métier.
#
# Alors, choisissez un domaine qui vous intéresse, étudiez en profondeur ses enjeux, et appréhendez un jeu de données spécifique.

# %% [markdown]
# ## Pandemie du Covid-19

# %% [markdown]
# ### Introduction

# %% [markdown]
# Au vu des changements soudains dans les paradigmes mondiaux  à cause de la pandémie du nouveau coronavirus, Covid__19 je trouve plus que pertinent de mettre mon savoir faire comme data analyst en fonction d’enrichir la recherche pour comprendre le fonctionnement de transmission de la maladie.

# %% [markdown]
# #### Contexte

# %% [markdown]
# Les coronavirus forment une vaste famille de virus qui peuvent être pathogènes chez l’homme et chez l’animal. On sait que, chez l’être humain, plusieurs coronavirus peuvent entraîner des infections respiratoires dont les manifestations vont du simple rhume à des maladies plus graves comme le syndrome respiratoire du Moyen-Orient (MERS) et le syndrome respiratoire aigu sévère (SRAS). Le dernier coronavirus qui a été découvert est responsable de la maladie à coronavirus 2019 (COVID-19).
# La COVID-19 est la maladie infectieuse causée par le dernier coronavirus qui a été découvert. Ce nouveau virus et cette maladie étaient inconnus avant l’apparition de la flambée à Wuhan (Chine) en décembre 2019.
#
# Le 20 janvier 2020, le point focal national RSI de la République de Corée a signalé le premier cas de nouveau coronavirus en République de Corée. Il s’agit d’une femme de 35 ans, de nationalité chinoise, résidant à Wuhan (province du Hubei, Chine).
#
# La patiente a présenté les symptômes suivants : fièvre, frissons et douleurs musculaires, le 18 janvier, alors qu’elle se trouvait à Wuhan. Elle s’est rendue dans un hôpital local à Wuhan et le diagnostic posé initialement a été celui d’un rhume. Le 19 janvier, à son arrivée à l’aéroport international d’Incheon (Corée du Sud), la patiente avait de la fièvre (38,3°C). Elle a été transférée dans un hôpital d’isolement désigné à cet effet pour être soumise à des tests de dépistage et bénéficier d’un traitement. Les tests ont donné un résultat positif à la RT-PCR (amplification génique après transcription inverse) pour les coronavirus ; le séquençage effectué ensuite, le 20 janvier, par les Centers for Disease Control and Prevention de Corée (KCDC) ont permis de confirmer que les résultats étaient positifs pour le nouveau coronavirus (2019-nCoV). Au moment du dépistage, la patiente présentait les symptômes suivants : frissons, écoulement nasal et douleurs musculaires.
#
# La patiente a indiqué ne s’être rendue sur aucun marché, y compris le marché aux poissons de Huanan ; elle n’a pas non plus eu de contact connu avec des cas confirmés de 2019-nCoV ou des animaux sauvages dans la ville de Wuhan.
#
# La patiente est actuellement à l’isolement et reçoit un traitement ; son état est stable.

# %% [markdown]
# Les symptômes les plus courants de la COVID-19 sont la fièvre, la fatigue et une toux sèche. Certains patients présentent des douleurs, une congestion nasale, un écoulement nasal, des maux de gorge ou une diarrhée. Ces symptômes sont généralement bénins et apparaissent de manière progressive. Certaines personnes, bien qu’infectées, ne présentent aucun symptôme et se sentent bien. La plupart (environ 80 %) des personnes guérissent sans avoir besoin de traitement particulier. Environ une personne sur six contractant la maladie présente des symptômes plus graves, notamment une dyspnée. Les personnes âgées et celles qui ont d’autres problèmes de santé (hypertension artérielle, problèmes cardiaques ou diabète) ont plus de risques de présenter des symptômes graves. Toute personne qui a de la fièvre, qui tousse et qui a des difficultés à respirer doit consulter un médecin.

# %% [markdown]
# a COVID-19 est transmise par des personnes porteuses du virus. La maladie peut se transmettre d’une personne à l’autre par le biais de gouttelettes respiratoires expulsées par le nez ou par la bouche lorsqu’une personne tousse ou éternue. Ces gouttelettes peuvent se retrouver sur des objets ou des surfaces autour de la personne en question. On peut alors contracter la COVID-19 si on touche ces objets ou ces surfaces et si on se touche ensuite les yeux, le nez ou la bouche. Il est également possible de contracter la COVID-19 en inhalant des gouttelettes d’une personne malade qui vient de tousser ou d’éternuer. C’est pourquoi il est important de se tenir à plus d’un mètre d’une personne malade.
#
# L’OMS examine les travaux de recherche en cours sur la manière dont la COVID-19 se propage et elle continuera à communiquer les résultats actualisés.

# %% [markdown]
# #### Contexte mondial

# %% [markdown]
# A l’heure actuelle des strictes mesure  pour ralentir la propagation du virus sont mis en p^ace pour les différents pays au niveau mondial.
# Ainsi, l'objectif des mesures politiques prises par les États (interdiction des rassemblements, mise en quarantaine, fermeture des écoles, transports, etc.) est “d'aplatir la courbe” de l'épidémie. Autrement dit, ralentir le rythme des nouvelles contaminations de façon à étaler dans le temps le nombre de cas nécessitant une hospitalisation.

# %% [markdown]
# ![covid-19-curves-graphic-social-v3.gif](attachment:covid-19-curves-graphic-social-v3.gif)

# %% [markdown]
# Le gif ci-dessus est réalisé à partir d'un schéma des Centres de contrôle des maladies américains à propos des épidémies de grippe. Il montre qu'en l'absence de mesures de protection ou de confinement, le nombre de cas augmente rapidement et surpasse les capacités de prise en charge des patients sévèrement atteints à l'hôpital (ligne en pointillés). Les mesures individuelles ou collectives permettent de retarder le pic épidémique pour étaler dans le temps le nombre de cas d'infection. L'épidémie n'est pas empêchée, mais suffisamment ralentie pour permettre aux hôpitaux de s'occuper correctement des malades. Plus le nombre de cas augmente rapidement, plus les mesures pour limiter les nouvelles contaminations deviennent nécessaire.

# %% [markdown]
# ### Missions

# %% [markdown]
# 1. Changements dans le nombre de cas touchés au fil du temps
# 2. Évolution des cas au fil du temps au niveau des pays
# 3. Créer un modèle prédictif performent

# %% [markdown]
# ### Les données

# %% [markdown]
# Source kaggle : https://www.kaggle.com/sudalairajkumar/novel-corona-virus-2019-dataset#covid_19_data.csv

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import statsmodels.api as sm
import statsmodels.formula.api as smf
from statsmodels.tsa.stattools import acf, pacf
from statsmodels.tsa.api import ExponentialSmoothing
from statsmodels.tsa.api import SARIMAX
from statsmodels.tsa.seasonal import seasonal_decompose

from scipy.stats import shapiro
import scipy

from sklearn import linear_model
from sklearn.metrics import mean_squared_error


from plotly.offline import iplot
from plotly import tools
import plotly.graph_objects as go
import plotly.express as px
import plotly.offline as py
import plotly.figure_factory as ff

from bokeh.plotting import output_notebook, figure, show
from bokeh.models import ColumnDataSource, Div, Select, Button, ColorBar, CustomJS
from bokeh.layouts import row, column, layout
from bokeh.transform import cumsum, linear_cmap
from bokeh.palettes import Blues8, Spectral3
from bokeh.plotting import figure, output_file, show

from funtions import *



output_notebook()

py.init_notebook_mode(connected=True)

# %% [markdown]
# ### Import des données

# %%
df= pd.read_csv('covid_19_data.csv')

# %%
df.head()

# %%
df.columns= ['SNo','Date', 'State' ,'Country',' Last Update','Confirmed','Deaths','Recovered']

# %% [markdown]
# ### Nettoyage des données

# %%
main_df = df[['Date', 'Country', 'Confirmed','Deaths','Recovered']]
main_df.head()

# %%
main_df.head()

# %%
main_df.describe()

# %%
main_df = main_df.dropna()

# %%
main_df.count()

# %% [markdown]
# ### Exploration des données

# %%
#group by country
df_by_country =main_df.groupby(['Country']).sum()

# %%
#group by date
df_by_date =main_df.groupby(['Date']).sum()

# %%
df_by_date.head()

# %%
df_by_date =df_by_date.reset_index()

df_by_date.head()

# %%
#transforming date feature in datetime
df_by_date.Date=pd.to_datetime(df_by_date.Date)

# %%
df_by_date.index= df_by_date['Date']

# %%
#data correlation
df_by_date.corr()

# %%
# data confirmed cases plot
a =df_by_date['Confirmed'].plot(figsize=(14,4),label="Confirmed ")

a.legend()
plt.savefig('confirmed.png')

# %%
# data deaths cases plot
b =df_by_date['Deaths'].plot(figsize=(14,4),label="Deaths", color ='red')

b.legend()
plt.savefig('Deaths.png')

# %%
# data recovered cases plot
c =df_by_date['Recovered'].plot(figsize=(14,4),label="Recovered",  color ='green')

c.legend()
plt.savefig('Recovered.png')

# %%
# all data plotting
plt.figure(figsize=(42, 7))
plt.plot(df_by_date.index, df_by_date['Deaths'], color='r')
plt.plot(df_by_date.index, df_by_date['Recovered'], color='green')
plt.plot(df_by_date.index, df_by_date['Confirmed'], color='blue')
plt.legend(['Deaths', 'Recoveries','Confirmed'], loc='best', fontsize=20)
plt.title('# of Coronavirus Cases', size=20)
plt.xlabel('Time', size=20)
plt.ylabel('# of Cases', size=20)
plt.xticks(size=15)
plt.show()

# %% [markdown]
# ## Mission 1

# %% [markdown]
# Changements dans le nombre de cas touchés au fil du temps

# %%
#plotting data cases over time
temp = main_df.groupby(['Date', 'Country'])['Confirmed'].sum().reset_index()
temp['Date'] = pd.to_datetime(temp['Date'])
temp['Date'] = temp['Date'].dt.strftime('%m/%d/%Y')
temp['size'] = temp['Confirmed'].pow(0.3) * 3.5

fig = px.scatter_geo(temp, locations="Country", locationmode='country names', 
                     color="Confirmed", size='size', hover_name="Country", 
                     range_color=[1,100],
                     projection="natural earth", animation_frame="Date", 
                     title='COVID-19: Cases Over Time', color_continuous_scale="greens")
fig.show()

# %%
#plotting data cases over time
temp = main_df.groupby(['Date', 'Country'])['Deaths'].sum().reset_index()
temp['Date'] = pd.to_datetime(temp['Date'])
temp['Date'] = temp['Date'].dt.strftime('%m/%d/%Y')
temp['size'] = temp['Deaths'].pow(0.3) * 3.5

fig = px.scatter_geo(temp, locations="Country", locationmode='country names', 
                     color="Deaths", size='size', hover_name="Country", 
                     range_color=[1,100],
                     projection="natural earth", animation_frame="Date", 
                     title='COVID-19: Fatalities Over Time', color_continuous_scale="purp")
fig.show()

# %%
#plotting how the virus spread worlwide
Country=pd.DataFrame()
#temp = train_df.groupby(["Country/Region"])["ConfirmedCases"].sum().reset_index()
temp = main_df.loc[main_df["Date"]==main_df["Date"][len(main_df)-1]].groupby(['Country'])["Confirmed"].sum().reset_index()
Country['Name']=temp["Country"]
Country['Values']=temp["Confirmed"]

fig = px.choropleth(Country, locations='Name',
                    locationmode='country names',
                    color="Values")
fig.update_layout(title="Corona spread on 06-04-2020")
fig.show()

# %% [markdown]
# Observations : À partir de ces graphiques, nous pouvons voir clairement que la maladie se propage bien en Chine, et nous pouvons également observer que l’Iran, l’Italie et les États-Unis suivent la tendance de la Chine et ont des chiffres élevés.

# %% [markdown]
# ### Mission 2

# %% [markdown]
# Évolution des cas au fil du temps au niveau des pays

# %%
Disease_through_Country = pd.DataFrame()
Disease_through_Country = main_df.groupby(["Country"]).sum().reset_index()


Names = ["Confirmed","Deaths"]
for i in Names:
    Disease_through_Country[i+"_percentage"] = Disease_through_Country[i]/Disease_through_Country[Names].sum(axis=1)*100
    Disease_through_Country[i+"_angle"] = Disease_through_Country[i+"_percentage"]/100 * 2*np.pi
    
Disease_through_Country_plot = pd.DataFrame({'class': ["Confirmed","Deaths"],
                                              'percent': [float('nan'), float('nan')],
                                              'angle': [float('nan'), float('nan')],
                                              'color': [ '#718dbf', '#e84d60']})
Disease_through_Country_plot

# %%
# Create the ColumnDataSource objects "s2" and "s2_plot"
s2 = ColumnDataSource(Disease_through_Country)
s2_plot = ColumnDataSource(Disease_through_Country_plot)

# Create the Figure object "p2"
p2 = figure(plot_width=475, plot_height=550, y_range=(-0.5, 0.7),toolbar_location=None, tools=['hover'], tooltips='@percent{0.0}%')

# Add circular sectors to "p2"
p2.wedge(x=0, y=0, radius=0.8, source=s2_plot,start_angle=cumsum('angle', include_zero=True), end_angle=cumsum('angle'),fill_color='color', line_color=None, legend='class')

# Change parameters of "p2"
p2.axis.visible = False
p2.grid.grid_line_color = None
p2.legend.orientation = 'horizontal'
p2.legend.location = 'top_center'

# Create the custom JavaScript callback
callback2 = CustomJS(args=dict(s2=s2, s2_plot=s2_plot), code='''
    var ang = ['Confirmed_angle', 'Deaths_angle'];
    var per = ['Confirmed_percentage',  'Deaths_percentage'];
    if (cb_obj.value != 'Please choose...') {
        var disease = s2.data['Country'];
        var ind = disease.indexOf(cb_obj.value);
        for (var i = 0; i < ang.length; i++) {
            s2_plot.data['angle'][i] = s2.data[ang[i]][ind];
            s2_plot.data['percent'][i] = s2.data[per[i]][ind];
            
        }
    }
    else {
        for (var i = 0; i < ang.length; i++) {
            s2_plot.data['angle'][i] = undefined;
            s2_plot.data['percent'][i] = undefined;
        }

    }
    s2_plot.change.emit();
''')

# When changing the value of the dropdown menu execute "callback2"
options = ['Please choose...'] + list(s2.data['Country'])
select = Select(title='Country ', value=options[0], options=options)
select.js_on_change('value', callback2)

# Display "select" and "p2" as a column
show(column(select, p2))

# %%
#plotting date confirmed cases vs deaths worldwide
Data = main_df.groupby("Date").sum().reset_index()
Data["Date"]= pd.to_datetime(Data["Date"])
source = ColumnDataSource(Data)
p = figure(x_axis_type='datetime')



p.line(x='Date', y='Confirmed', line_width=2, source=source, legend='Confirmed Corona Cases')
p.line(x='Date', y='Deaths', line_width=2, source=source, color=Spectral3[2], legend='Death by Corona')

p.yaxis.axis_label = 'Activity of Corona period of time'
show(p)

# %%
df_by_country= df_by_country.sort_values('Confirmed', ascending = False)

# %%
from itertools import cycle, islice
discrete_col = list(islice(cycle(['orange', 'r', 'g', 'k', 'b', 'c', 'm']), None, len(df_by_country.head(30))))
plt.rcParams.update({'font.size': 14})
df_by_country.head(20).plot(figsize=(20,15), kind='barh', color=discrete_col)
plt.legend(["Confirmed Cases", "Fatalities"]);
plt.xlabel("Number of Covid-19 Affectees")
plt.title("First 20 Countries with Highest Confirmed Cases")
ylocs, ylabs = plt.yticks()
for i, v in enumerate(df_by_country.head(20)["Confirmed"][:]):
    plt.text(v+0.01, ylocs[i]-0.25, str(int(v)), fontsize=12)
for i, v in enumerate(df_by_country.head(20)["Deaths"][:]):
    if v > 0: #disply for only >300 fatalities
        plt.text(v+0.01,ylocs[i]+0.1,str(int(v)),fontsize=12)

# %%
import pycountry_convert as pc
import pycountry

class country_utils():
    def __init__(self):
        self.d = {}
    
    def get_dic(self):
        return self.d
    
    def get_country_details(self,country):
        """Returns country code(alpha_3) and continent"""
        try:
            country_obj = pycountry.countries.get(name=country)
            if country_obj is None:
                c = pycountry.countries.search_fuzzy(country)
                country_obj = c[0]
            continent_code = pc.country_alpha2_to_continent_code(country_obj.alpha_2)
            continent = pc.convert_continent_code_to_continent_name(continent_code)
            return country_obj.alpha_3, continent
        except:
            if 'Congo' in country:
                country = 'Congo'
            elif country == 'Diamond Princess' or country == 'Laos' or country == 'MS Zaandam'\
            or country == 'Holy See' or country == 'Timor-Leste':
                return country, country
            elif country == 'Korea, South' or country == 'South Korea':
                country = 'Korea, Republic of'
            elif country == 'Taiwan*':
                country = 'Taiwan'
            elif country == 'Burma':
                country = 'Myanmar'
            elif country == 'West Bank and Gaza':
                country = 'Gaza'
            else:
                return country, country
            country_obj = pycountry.countries.search_fuzzy(country)
            continent_code = pc.country_alpha2_to_continent_code(country_obj[0].alpha_2)
            continent = pc.convert_continent_code_to_continent_name(continent_code)
            return country_obj[0].alpha_3, continent
    
    def get_iso3(self, country):
        return self.d[country]['code']
    
    def get_continent(self,country):
        return self.d[country]['continent']
    
    def add_values(self,country):
        self.d[country] = {}
        self.d[country]['code'],self.d[country]['continent'] = self.get_country_details(country)
    
    def fetch_iso3(self,country):
        if country in self.d.keys():
            return self.get_iso3(country)
        else:
            self.add_values(country)
            return self.get_iso3(country)
        
    def fetch_continent(self,country):
        if country in self.d.keys():
            return self.get_continent(country)
        else:
            self.add_values(country)
            return self.get_continent(country)

# %%
df_tm = df.copy()
date = df_tm.Date.max()#get current date
df_tm = df_tm[df_tm['Date']==date]
obj = country_utils()
df_tm.State.fillna('',inplace=True)
df_tm['continent'] = df_tm.apply(lambda x: obj.fetch_continent(x['Country']), axis=1)
df_tm["world"] = "World" # in order to have a single root node
fig = px.treemap(df_tm, path=['world', 'continent', 'Country','State'], values='Confirmed',
                  color='Confirmed', hover_data=['Country'],
                  color_continuous_scale='dense', title='Current share of Worldwide COVID19 Cases')
fig.show()

# %%
fig = px.treemap(df_tm, path=['world', 'continent', 'Country','State'], values='Deaths',
                  color='Deaths', hover_data=['Country'],
                  color_continuous_scale='matter', title='Current share of Worldwide COVID19 Deaths')
fig.show()

# %% [markdown]
# Observation :
# Il y a deux points de fluctuation sur la période de Corona un entre 2-10-2020 et 2-15-2020 et l’autre à 3-10-2020 et 3-15-2020, ce qui est exactement une période d'un mois. Donc, il pourrait suivre un modèle cyclique, nous allons essayer d’explorer à partir de cette prespective dans ce notebook.

# %% [markdown]
# ### Propagation de la maladie  Chine, Italie, France, Etats-Unis

# %%
#plotting spread of Corona over a period of time in specific countries
China_cases = main_df.loc[main_df["Country"]=="Mainland China"].groupby("Date")["Confirmed"].sum().reset_index()
Italy_cases = main_df.loc[main_df["Country"]=="Italy"].groupby("Date")["Confirmed"].sum().reset_index()
France_cases = main_df.loc[main_df["Country"]=="France"].groupby("Date")["Confirmed"].sum().reset_index()
Usa_cases = main_df.loc[main_df["Country"]=="US"].groupby("Date")["Confirmed"].sum().reset_index()


fig = go.Figure()

fig.add_trace(go.Scatter(x=China_cases.Date, y=China_cases['Confirmed'], name="Cases in China",
                         line_color='deepskyblue'))

fig.add_trace(go.Scatter(x=Italy_cases.Date, y=Italy_cases['Confirmed'], name="Cases in Itlay",
                         line_color='red'))

fig.add_trace(go.Scatter(x=France_cases.Date, y=France_cases['Confirmed'], name="Cases in France",
                         line_color='green'))

fig.add_trace(go.Scatter(x=Usa_cases.Date, y=Usa_cases['Confirmed'], name="Cases in Usa",
                         line_color='yellow'))

fig.update_layout(title_text='Spread of Corona over a period of Time',
                  xaxis_rangeslider_visible=True)
fig.show()

# %%
#plotting spread of fatality through Corona over a period of time in specific countries
China_cases = main_df.loc[main_df["Country"]=="Mainland China"].groupby("Date")["Deaths"].sum().reset_index()
Italy_cases = main_df.loc[main_df["Country"]=="Italy"].groupby("Date")["Deaths"].sum().reset_index()
France_cases = main_df.loc[main_df["Country"]=="France"].groupby("Date")["Deaths"].sum().reset_index()
Usa_cases = main_df.loc[main_df["Country"]=="US"].groupby("Date")["Deaths"].sum().reset_index()


fig = go.Figure()

fig.add_trace(go.Scatter(x=China_cases.Date, y=China_cases['Deaths'], name="Fatalities in China",
                         line_color='deepskyblue'))

fig.add_trace(go.Scatter(x=Italy_cases.Date, y=Italy_cases['Deaths'], name="Fatalities in Itlay",
                         line_color='red'))

fig.add_trace(go.Scatter(x=France_cases.Date, y=France_cases['Deaths'], name="Fatalities in France",
                         line_color='green'))

fig.add_trace(go.Scatter(x=Usa_cases.Date, y=Usa_cases['Deaths'], name="Fatalities in Usa",
                         line_color='yellow'))

fig.update_layout(title_text='Fatality through Corona over a period of Time',
                  xaxis_rangeslider_visible=True)
fig.show()

# %% [markdown]
# ### Les deux pays plus touchés par la maladie :  Chine et Italie.

# %%
#creating China, Italy and the rest of the world df confirmed cases
china_data=main_df[main_df["Country"]=="Mainland China"]
Italy_data=main_df[main_df["Country"]=="Italy"]
rest_of_world=main_df[(main_df["Country"]!="Mainland China")&(main_df["Country"]!="Italy")]

datewise_china=china_data.groupby(["Date"]).agg({"Confirmed":'sum',"Recovered":'sum',"Deaths":'sum'})
datewise_Italy=Italy_data.groupby(["Date"]).agg({"Confirmed":'sum',"Recovered":'sum',"Deaths":'sum'})
datewise_restofworld=rest_of_world.groupby(["Date"]).agg({"Confirmed":'sum',"Recovered":'sum',"Deaths":'sum'})

# %%
#plotting confirmed cases
fig, (ax1, ax2, ax3) = plt.subplots(3, 1,figsize=(16,20))
ax1.plot(datewise_china["Confirmed"],label="Confirmed Cases of Mainland China",marker='o')
ax1.plot(datewise_Italy["Confirmed"],label="Confirmed Cases of Italy",marker='*')
ax1.plot(datewise_restofworld["Confirmed"],label="Confirmed Cases of Rest of the World",marker='o')
ax1.set_title("Confirmed Cases Plot")
ax1.set_ylabel("Number of Patients")
ax1.set_xlabel("Timestamp")
ax1.legend()

for tick in ax1.get_xticklabels():
    tick.set_rotation(45)
ax2.plot(datewise_china["Recovered"],label="Recovered Cases of Mainland China",marker='o')
ax2.plot(datewise_Italy["Recovered"],label="Recovered Cases of Italy",marker='*')
ax2.plot(datewise_restofworld["Recovered"],label="Recovered Cases of Rest of the World",marker='^')
ax2.set_title("Recovered Cases Plot")
ax2.set_ylabel("Number of Patients")
ax2.set_xlabel("Timestamp")
ax2.legend()

for tick in ax2.get_xticklabels():
    tick.set_rotation(90)
ax3.plot(datewise_china["Deaths"],label='Death Cases of Mainland China',marker='o')
ax3.plot(datewise_Italy["Deaths"],label='Death Cases of Italy',marker='*')
ax3.plot(datewise_restofworld["Deaths"],label="Deaths Cases of Rest of the World",marker='^')
ax3.set_title("Death Cases Plot")
ax3.set_ylabel("Number of Patients")
ax3.set_xlabel("Timestamp")
ax3.legend()
for tick in ax3.get_xticklabels():
    tick.set_rotation(90)

# %%
#creating China, Italy and the rest of the world df deaths cases
datewise_china["Mortality"]=(datewise_china["Deaths"]/datewise_china["Confirmed"])*100
datewise_Italy["Mortality"]=(datewise_Italy["Deaths"]/datewise_Italy["Confirmed"])*100
datewise_restofworld["Mortality"]=(datewise_restofworld["Deaths"]/datewise_restofworld["Confirmed"])*100
datewise_china["Recovery"]=(datewise_china["Recovered"]/datewise_china["Confirmed"])*100
datewise_Italy["Recovery"]=(datewise_Italy["Recovered"]/datewise_Italy["Confirmed"])*100
datewise_restofworld["Recovery"]=(datewise_restofworld["Recovered"]/datewise_restofworld["Confirmed"])*100

# %%
#plotting  China, Italy and the rest of the world'mortallity and recovery
fig, (ax1,ax2) = plt.subplots(2, 1,figsize=(16,20))
ax1.plot(datewise_china["Mortality"],label="Mortality Rate of Mainland China",marker='o')
ax1.plot(datewise_Italy["Mortality"],label="Mortality Rate of Italy",marker='*')
ax1.plot(datewise_restofworld["Mortality"],label="Mortality Rate of Rest of the World",marker='^')
ax1.axhline(datewise_china["Mortality"].mean(),linestyle='--',color='black',label="Mean Mortality Rate of China")
ax1.axhline(datewise_Italy["Mortality"].mean(),linestyle='--',color='red',label="Mean Mortality Rate of Italy")
ax1.axhline(datewise_restofworld["Mortality"].mean(),linestyle='--',color='yellow',label="Mean Mortality Rate of Rest of the World")
ax1.set_ylabel("Mortality Rate")
ax1.set_xlabel("Timestamp")
ax1.set_title("Mortality Rate comparison of Mainland China, Italy and Rest of the World")
ax1.legend()
for tick in ax1.get_xticklabels():
    tick.set_rotation(90)
ax2.plot(datewise_china["Recovery"],label="Recovery Rate of Mainland China",marker='o')
ax2.plot(datewise_Italy["Recovery"],label="Recovery Rate Italy",marker='*')
ax2.plot(datewise_restofworld["Recovery"],label="Recovery Rate Rest of the World",marker='^')
ax2.axhline(datewise_china["Recovery"].mean(),linestyle='--',color='black',label="Mean Recovery Rate of China")
ax2.axhline(datewise_Italy["Recovery"].mean(),linestyle='--',color='red',label="Mean Recovery Rate of Italy")
ax2.axhline(datewise_restofworld["Recovery"].mean(),linestyle='--',color='yellow',label="Mean Recovery Rate of Rest of the World")
ax2.set_ylabel("Recovery Rate")
ax2.set_xlabel("Timestamp")
ax2.set_title("Recovery Rate comparison of Mainland China, Italy and Rest of the World")
ax2.legend()
for tick in ax2.get_xticklabels():
    tick.set_rotation(90)

# %% [markdown]
# Observation :
#
# En observant les cas confirmés et les décès au fil du temps l’Italie est sur le point de répéter le chemin de la Chine, tandis que le taux de mortalité en Italie semble être le pire de tous et il suit une tendance croissante.

# %% [markdown]
# ### Mission 3

# %% [markdown]
# Créer un modèle prédictif performent

# %% [markdown]
# #### Holt's Linear Model

# %%
#split data
model_train=df_by_date.iloc[:int(df_by_date.shape[0]*0.80)]
valid=df_by_date.iloc[int(df_by_date.shape[0]*0.80):]

# %%
model_train.index= model_train['Date']

# %%
#Holt model
from statsmodels.tsa.api import Holt,SimpleExpSmoothing,ExponentialSmoothing
holt=Holt(np.asarray(model_train["Confirmed"])).fit(smoothing_level=0.1, smoothing_slope=0.9)
y_pred=valid.copy()

# %%
#holt forecast and MSE printing
y_pred["Holt"]=holt.forecast(len(valid))
print("Mean Squared Error:",np.sqrt(mean_squared_error(y_pred["Confirmed"],y_pred["Holt"])))

# %%
#plotting model results
plt.figure(figsize=(10,5))
plt.plot(model_train.Confirmed,label="Train Set",marker='o')
valid.Confirmed.plot(label="Validation Set",marker='*')
y_pred.Holt.plot(label="Holt's Linear Model Predicted Set",marker='^')
plt.ylabel("Confirmed Cases")
plt.xlabel("Date Time")
plt.xticks(rotation=90)
plt.legend()

# %%
#model evaluation 
model_eval(y_pred["Confirmed"],y_pred["Holt"])

# %% [markdown]
# #### Holt's Winter Modèle

# %%
#Holt Winters model
es=ExponentialSmoothing(np.asarray(model_train['Confirmed']),seasonal_periods=5,trend='mul', seasonal='add').fit()

# %%
#model forecast
y_pred["Holt's Winter Model"]=es.forecast(len(valid))

# %%
#MSE calculating
np.sqrt(mean_squared_error(y_pred["Confirmed"],y_pred["Holt's Winter Model"]))

# %%
#plotting model results
plt.figure(figsize=(10,5))
plt.plot(model_train.Confirmed,label="Train Set",marker='o')
valid.Confirmed.plot(label="Validation Set",marker='*')
y_pred["Holt\'s Winter Model"].plot(label="Holt's Winter Model Predicted Set",marker='^')
plt.ylabel("Confirmed Cases")
plt.xlabel("Date Time")
plt.xticks(rotation=90)
plt.legend()

# %%
#model evaluation
model_eval(y_pred["Confirmed"],y_pred["Holt's Winter Model"])

# %% [markdown]
# #### ARIMA Modèle

# %%
# ACF plotting
from pandas.plotting import autocorrelation_plot
plt.figure(figsize=(10, 5))
autocorrelation_plot(df_by_date["Confirmed"])

# %%
#data decompose
sm.tsa.seasonal_decompose(model_train["Confirmed"]).plot()
plt.show()

# %%
# data stationary test
from statsmodels.tsa.stattools import adfuller
print("Results of Dickey-Fuller test for Original Time Series")
dftest = adfuller(model_train["Confirmed"], autolag='AIC')
dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
for key,value in dftest[4].items():
    dfoutput['Critical Value (%s)'%key] = value
print(dfoutput)

# %%
#log transforming data in add model
log_series=np.log(model_train["Confirmed"])

# %%
# data stationary test
print("Results of Dickey-Fuller test for Log Transformed Time-Series")
dftest = adfuller(log_series, autolag='AIC')
dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
for key,value in dftest[4].items():
    dfoutput['Critical Value (%s)'%key] = value
print(dfoutput)

# %%
#data decompose
sm.tsa.seasonal_decompose(log_series).plot()
plt.show()

# %% [markdown]
# ##### ARIMA

# %%
#ARIMA model
from statsmodels.tsa.arima_model import ARIMA
model_arima=ARIMA(log_series,(1,1,1))
model_arima_fit=model_arima.fit()

# %%
#model forecast
prediction_arima=model_arima_fit.forecast(len(valid))[0]
y_pred["ARIMA Model Prediction"]=list(np.exp(prediction_arima))

# %%
np.sqrt(mean_squared_error(list(valid["Confirmed"]),np.exp(prediction_arima)))

# %%
#plotting model results
plt.figure(figsize=(20,5))
plt.plot(model_train.index,model_train["Confirmed"],label="Train Set",marker='o')
plt.plot(valid.index,valid["Confirmed"],label="Validation Set",marker='o')
plt.plot(y_pred["ARIMA Model Prediction"],label="ARIMA Model Prediction Set",marker='o')
plt.legend()
plt.xlabel("Date Time")
plt.ylabel('Confirmed Cases')
plt.xticks(rotation=90)

# %%
print(model_arima_fit.summary())

# %%
# Plot residual errors
residuals = pd.DataFrame(model_arima_fit.resid)
fig, ax = plt.subplots(1,2)
residuals.plot(title="Residuals", ax=ax[0])
residuals.plot(kind='kde', title='Density', ax=ax[1])
plt.show()

# %%
# ljung box test
sm.stats.acorr_ljungbox(model_arima_fit.resid, lags=[28], return_df=True)

# %%
#model evaluation
model_eval(valid["Confirmed"],np.exp(prediction_arima))

# %% [markdown]
# ### Modèles de Machine Learning

# %% [markdown]
# ##### Regression linèaire

# %%
df_by_date["Date"]=df_by_date.index-df_by_date.index[0]
df_by_date["Date"]=df_by_date["Date"].dt.days

# %%
#split data
train_ml=df_by_date.iloc[:int(df_by_date.shape[0]*0.80)]
valid_ml=df_by_date.iloc[int(df_by_date.shape[0]*0.80):]

# %%
#linear regression model
reg=LinearRegression(normalize=True)

# %%
#model fitting
reg.fit(np.array(train_ml["Date"]).reshape(-1,1),np.array(train_ml["Confirmed"]).reshape(-1,1))

# %%
#predicting
prediction_valid_reg=reg.predict(np.array(valid_ml["Date"]).reshape(-1,1))

# %%
print("Root Mean Square Value:",np.sqrt(mean_squared_error(valid_ml["Confirmed"],prediction_valid_reg)))

# %%
#plotting model prediction
plt.figure(figsize=(11,6))
prediction_reg=reg.predict(np.array(df_by_date["Date"]).reshape(-1,1))
plt.plot(df_by_date["Confirmed"],label="Actual Confirmed Cases")
plt.plot(df_by_date.index,prediction_reg, linestyle='--',label="Predicted Confirmed Cases using Linear Regression",color='black')
plt.xlabel('Time')
plt.ylabel('Confirmed Cases')
plt.xticks(rotation=90)
plt.legend()

# %%
#model summary
X = train_ml["Confirmed"]
X = sm.add_constant(X)
y = train_ml["Date"]

model = sm.OLS(y, X)
results = model.fit()
print(results.summary())

# %%
#residuals analysis
linear_regression_analysis(results)

# %% [markdown]
# ##### Support Vector Machine

# %%
#svm model
from sklearn.svm import SVR
svm=SVR(C=1,degree=8,kernel='poly',epsilon=0.01)

# %%
#fitting model
svm.fit(np.array(train_ml["Date"]).reshape(-1,1),np.array(train_ml["Confirmed"]).reshape(-1,1))

# %%
#model prediction
prediction_valid_svm=svm.predict(np.array(valid_ml["Date"]).reshape(-1,1))

# %%
#printing RMS
print("Root Mean Square Value:",np.sqrt(mean_squared_error(valid_ml["Confirmed"],prediction_valid_svm)))

# %%
#plotting model predictions
plt.figure(figsize=(11,6))
prediction_svm=svm.predict(np.array(df_by_date["Date"]).reshape(-1,1))
plt.plot(df_by_date["Confirmed"],label="Train Confirmed Cases")
plt.plot(df_by_date.index,prediction_svm, linestyle='--',label="Best Fit for SVR",color='black')
plt.xlabel('Time')
plt.ylabel('Confirmed Cases')
plt.xticks(rotation=90)
plt.legend()

# %% [markdown]
# #### ARIMA modèle pour prédire les décédés.

# %%
y_pred_deaths=valid.copy()

# %%
#ACF
plt.figure(figsize=(10, 5))
autocorrelation_plot(df_by_date["Deaths"])

# %%
# data decompose
sm.tsa.seasonal_decompose(model_train["Deaths"]).plot()
plt.show()

# %%
# data stationary test
print("Results of Dickey-Fuller test for Original Time Series")
dftest = adfuller(model_train["Deaths"], autolag='AIC')
dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
for key,value in dftest[4].items():
    dfoutput['Critical Value (%s)'%key] = value
print(dfoutput)

# %%
log_series_deaths=np.log(model_train["Deaths"])

# %%
# data stationary test post log
print("Results of Dickey-Fuller test for Log Transformed Time-Series")
dftest = adfuller(log_series_deaths, autolag='AIC')
dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
for key,value in dftest[4].items():
    dfoutput['Critical Value (%s)'%key] = value
print(dfoutput)

# %%
#data decompose
sm.tsa.seasonal_decompose(log_series_deaths).plot()
plt.show()

# %%
#ARIMA model
model_arima_deaths=ARIMA(log_series_deaths,(2,1,0))
model_arima_fit_deaths=model_arima_deaths.fit()

# %%
print(model_arima_fit_deaths.summary())

# %%
#model forecast
prediction_arima_deaths=model_arima_fit_deaths.forecast(len(valid))[0]
y_pred_deaths["ARIMA Model Prediction"]=list(np.exp(prediction_arima_deaths))
np.exp(prediction_arima_deaths)

# %%
#MSE
np.sqrt(mean_squared_error(list(valid["Deaths"]),np.exp(prediction_arima_deaths)))

# %%
#plotting model predictions
plt.figure(figsize=(10,5))
plt.plot(model_train.index,model_train["Deaths"],label="Train Set",marker='o')
plt.plot(valid.index,valid["Deaths"],label="Validation Set",marker='o')
plt.plot(y_pred_deaths["ARIMA Model Prediction"],label="ARIMA Model Prediction Set",marker='o')
plt.legend()
plt.xlabel("Date Time")
plt.ylabel('Death Cases')
plt.xticks(rotation=90)

# %%
sm.stats.acorr_ljungbox(model_arima_fit_deaths.resid, lags=[28], return_df=True)

# %%
#model evaluation
model_eval(valid["Deaths"],np.exp(prediction_arima_deaths))

# %%
shapiro(model_arima_fit_deaths.resid)

# %% [markdown]
# #### SVM modèle pour prédire les décédés.

# %%
#fitting the model
svm.fit(np.array(train_ml["Date"]).reshape(-1,1),np.array(train_ml["Deaths"]).reshape(-1,1))

# %%
prediction_valid_svm=svm.predict(np.array(valid_ml["Date"]).reshape(-1,1))

# %%
print("Root Mean Square Value:",np.sqrt(mean_squared_error(valid_ml["Deaths"],prediction_valid_svm)))

# %%
#plotting model's predictions
plt.figure(figsize=(11,6))
prediction_svm=svm.predict(np.array(df_by_date["Date"]).reshape(-1,1))
plt.plot(df_by_date["Deaths"],label="Train Deaths Cases")
plt.plot(df_by_date.index,prediction_svm, linestyle='--',label="Best Fit for SVR",color='black')
plt.xlabel('Time')
plt.ylabel('Deaths Cases')
plt.xticks(rotation=90)
plt.legend()

# %% [markdown]
# ###### France : l'état de lieu

# %%
#France df
df_france = main_df.loc[main_df["Country"]=="France"]

# %% [markdown]
# Pour l'année 2020, la population légale atteint 66 524 000 habitants en France

# %%
df_france['population']=  66524000

# %%
df_france = df_france.groupby(df_france['Date']).sum()

# %%
df_france =df_france.reset_index()

# %%
#plotting France data
fig = go.Figure()

fig.add_trace(go.Scatter(x=df_france.Date, y=df_france['Confirmed'], name="Confirmed",
                         line_color='deepskyblue'))

fig.add_trace(go.Scatter(x=df_france.Date, y=df_france['Recovered'], name="Recovered ",
                         line_color='green'))

fig.add_trace(go.Scatter(x=df_france.Date, y=df_france['Deaths'], name="Fatalities ",
                         line_color='red'))


fig.update_layout(title_text='France through Corona over a period of Time',
                  xaxis_rangeslider_visible=True)
fig.show()

# %%
df_france["Mortality"]=(df_france["Deaths"]/df_france["Confirmed"])*100
df_france["percent_pop_confirmed"]=((df_france["Confirmed"]*100)/df_france["population"])
df_france["percent_pop_death"]=((df_france["Deaths"]*100)/df_france["population"])
df_france["percent_pop_recovery"]=((df_france["Recovered"]*100)/df_france["population"])

# %%
df_france.head()

# %%
#plotting france'data
fig = go.Figure()

fig.add_trace(go.Scatter(x=df_france.Date, y=df_france['Mortality'], name="Mortality",
                         line_color='deepskyblue'))

fig.add_trace(go.Scatter(x=df_france.Date, y=df_france['percent_pop_confirmed'], name="Confirmed's percent ",
                         line_color='green'))

fig.add_trace(go.Scatter(x=df_france.Date, y=df_france['percent_pop_death'], name="Death's percent ",
                         line_color='red'))
fig.add_trace(go.Scatter(x=df_france.Date, y=df_france['percent_pop_recovery'], name="Recovered's percent ",
                         line_color='yellow'))

fig.update_layout(title_text='France through Corona over a period of Time',
                  xaxis_rangeslider_visible=True)
fig.show()

# %% [markdown]
# #### Predire les décédés en France

# %% [markdown]
# ##### Modèle Arima

# %%
df_fr= df_france[['Date', 'Deaths']]

# %%
#delete null values
df_fr= df_fr[(df_fr['Deaths'] > 0) | (df_fr['Deaths'].isnull())]

# %%
df_fr.Date=pd.to_datetime(df_fr.Date)

# %%
#split data
model_train=df_fr.iloc[:int(df_fr.shape[0]*0.80)]
valid=df_fr.iloc[int(df_fr.shape[0]*0.80):]

# %%
model_train.index= model_train['Date']

# %%
y_pred_deaths=valid.copy()

# %%
#ACF
plt.figure(figsize=(10, 5))
autocorrelation_plot(model_train["Deaths"])

# %%
#data decompose
sm.tsa.seasonal_decompose(model_train["Deaths"]).plot()
plt.show()

# %%
# data stationary test
print("Results of Dickey-Fuller test for Original Time Series")
dftest = adfuller(model_train["Deaths"], autolag='AIC')
dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
for key,value in dftest[4].items():
    dfoutput['Critical Value (%s)'%key] = value
print(dfoutput)

# %%
log_series_deaths=np.log(model_train["Deaths"])

# %%
# data stationary test post log
print("Results of Dickey-Fuller test for Log Transformed Time-Series")
dftest = adfuller(log_series_deaths, autolag='AIC')
dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
for key,value in dftest[4].items():
    dfoutput['Critical Value (%s)'%key] = value
print(dfoutput)

# %%
#data decompose
sm.tsa.seasonal_decompose(log_series_deaths).plot()
plt.show()

# %%
#ARIMA model
model_arima_deaths=ARIMA(log_series_deaths,(1, 1,1))
model_arima_fit_deaths=model_arima_deaths.fit()

# %%
print(model_arima_fit_deaths.summary())

# %%
#model forecast
prediction_arima_deaths=model_arima_fit_deaths.forecast(len(valid))[0]
y_pred_deaths["ARIMA Model Prediction"]=list(np.exp(prediction_arima_deaths))
np.exp(prediction_arima_deaths)

# %%
np.sqrt(mean_squared_error(list(valid["Deaths"]),np.exp(prediction_arima_deaths)))

# %%
valid.index= valid['Date']

# %%
y_pred_deaths.index= y_pred_deaths['Date']

# %%
#plotting model's predictions
plt.figure(figsize=(10,5))
plt.plot(model_train.index,model_train["Deaths"],label="Train Set",marker='o')
plt.plot(valid.index,valid["Deaths"],label="Validation Set",marker='o')
plt.plot(y_pred_deaths["ARIMA Model Prediction"],label="ARIMA Model Prediction Set",marker='o')
plt.legend()
plt.xlabel("Date Time")
plt.ylabel('Death Cases')
plt.xticks(rotation=90)

# %%
#model evaluation
model_eval(valid["Deaths"],np.exp(prediction_arima_deaths))

# %%
sm.stats.acorr_ljungbox(model_arima_fit_deaths.resid, lags=[28], return_df=True)

# %% [markdown]
# ####  SVM : France

# %%
df_fr= df_france[['Date', 'Deaths']]

# %%
df_fr= df_fr[(df_fr['Deaths'] > 0) | (df_fr['Deaths'].isnull())]

# %%
df_fr.Date=pd.to_datetime(df_fr.Date)

# %%
df_fr["Date"]=df_fr.index-df_fr.index[0]

# %%
#data split
model_train=df_fr.iloc[:int(df_fr.shape[0]*0.80)]
valid=df_fr.iloc[int(df_fr.shape[0]*0.80):]

# %%
#SVM model
svm=SVR(C=1,degree=8,kernel='poly',epsilon=1)

# %%
#model fitting
svm.fit(np.array(model_train["Date"]).reshape(-1,1),np.array(model_train["Deaths"]).reshape(-1,1).ravel())

# %%
prediction_valid_svm=svm.predict(np.array(valid["Date"]).reshape(-1,1))

# %%
prediction_valid_svm

# %%
#RMS
print("Root Mean Square Value:",np.sqrt(mean_squared_error(valid["Deaths"],prediction_valid_svm)))

# %%
#plotting model's predictions
plt.figure(figsize=(11,6))
prediction_svm=svm.predict(np.array(df_fr["Date"]).reshape(-1,1))
plt.plot(df_fr["Deaths"],label="Train Deaths Cases")
plt.plot(df_fr.index,prediction_svm, linestyle='--',label="Best Fit for SVR",color='black')
plt.xlabel('Time')
plt.ylabel('Deaths Cases')
plt.xticks(rotation=90)
plt.legend()
